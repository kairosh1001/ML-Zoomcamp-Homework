# %%
import pandas as pd
import numpy as np
import onnx
import io
import requests
from PIL import Image
import torchvision.transforms as transforms
import onnxruntime as ort
# Out:
# 2026-06-02 10:43:39.878768293 [W:onnxruntime:Default, device_discovery.cc:133 GetPciBusId] Skipping pci_bus_id for PCI path at "/sys/devices/LNXSYSTM:00/LNXSYBUS:00/PNP0A03:00/device:07/VMBUS:01/5620e0c7-8062-4dce-aeb7-520c7ef76171" because filename "5620e0c7-8062-4dce-aeb7-520c7ef76171" did not match expected pattern of [0-9a-f]+:[0-9a-f]+:[0-9a-f]+[.][0-9a-f]+

# %%
PREFIX="https://github.com/alexeygrigorev/large-datasets/releases/download/hairstyle"
DATA_URL = f"{PREFIX}/hair_classifier_v1.onnx.data"
MODEL_URL = f"{PREFIX}/hair_classifier_v1.onnx"
# !wget $DATA_URL
# !wget $MODEL_URL
# Out:
# --2026-06-02 09:49:54--  https://github.com/alexeygrigorev/large-datasets/releases/download/hairstyle/hair_classifier_v1.onnx.data
# Resolving github.com (github.com)... 20.207.73.82
# Connecting to github.com (github.com)|20.207.73.82|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !pip install onnx

# %%
model_path = "hair_classifier_v1.onnx"
model = onnx.load(model_path)

# %%
graph = model.graph

# %%
for input_node in graph.input:
    print(input_node.name)
print("-" * 30)
for output_node in graph.output:
    print(output_node.name)
# Out:
# input
# ------------------------------
# output

# %% [markdown]
# Question 1 answer: output

# %%
# !pip install pillow

# %%
from io import BytesIO
from urllib import request

from PIL import Image

def download_image(url):
    with request.urlopen(url) as resp:
        buffer = resp.read()
    stream = BytesIO(buffer)
    img = Image.open(stream)
    return img


def prepare_image(img, target_size):
    if img.mode != 'RGB':
        img = img.convert('RGB')
    img = img.resize(target_size, Image.NEAREST)
    return img

# %% [markdown]
# Question 2 answer: 200X200

# %%
# !pip install requests pillow torchvision
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 45.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.3/532.3 MB 20.3 MB/s  0:00:13 eta 0:00:010:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.2/366.2 MB 32.8 MB/s  0:00:08 eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.1/170.1 MB 42.9 MB/s  0:00:03 eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.0/206.0 MB 45.2 MB/s  0:00:04 eta 0:00:010:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 MB 51.1 MB/s  0:00:01s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.5/201.5 MB 36.4 MB/s  0:00:05 eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 30.9 MB/s  0:00:00ta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 MB 31.0 MB/s  0:00:08 eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 48.8 MB/s  0:00:00ta 0:00:01
# ...

# %%
train_transforms = transforms.Compose([
    transforms.Resize((200, 200)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# %%
img_url = "https://habrastorage.org/webt/yf/_d/ok/yf_dokzqy3vcritme8ggnzqlvwa.jpeg"

# %%
response = requests.get(img_url, timeout=10)
img = Image.open(io.BytesIO(response.content)).convert('RGB')
input_tensor = train_transforms(img)
input_tensor = input_tensor.unsqueeze(0)

# %%
# Indexing: [Batch 0, Channel 0, Row 0, Column 0]
first_pixel_r = input_tensor[0, 0, 0, 0].item()

print(f"The preprocessed R-channel value of the first pixel is: {first_pixel_r}")
# Out:
# The preprocessed R-channel value of the first pixel is: -1.0561692714691162

# %% [markdown]
# Q3 answer is -1.073

# %%
# !pip install onnxruntime
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 35.3 MB/s  0:00:00 eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [onnxruntime] 1/2 [onnxruntime]
# ...

# %%
session = ort.InferenceSession(model_path)

# %%
input_name = session.get_inputs()[0].name
output_name = session.get_outputs()[0].name

# %%
x = input_tensor.numpy().astype('float32')

# %%
outputs = session.run([output_name], {input_name: x})

# %%
predictions = outputs[0]
print("Raw Model Output:", predictions)
# Out:
# Raw Model Output: [[0.72769666]]

# %%
# !jupyter nbconvert --to script Homework8.ipynb
# Out:
# [NbConvertApp] Converting notebook Homework8.ipynb to script
# [NbConvertApp] Writing 2610 bytes to Homework8.py

# %% [markdown]
# Q5 answer: 269mb

# %%
url = "http://localhost:8080/2015-03-31/functions/function/invocations"

# The specific payload containing the image link from your assignment
data = {
    "url": "https://habrastorage.org/webt/yf/_d/ok/yf_dokzqy3vcritme8ggnzqlvwa.jpeg"
}

# Send the POST request to your container
response = requests.post(url, json=data)

# Print out the prediction results!
print("Model Output Response:")
print(response.json())
# Out:
# Model Output Response:
# {'prediction': [[-0.10220836102962494]]}

# %% [markdown]
# Q6 answer: -0.10
