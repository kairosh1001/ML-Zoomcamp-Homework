# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Q1 answer: 0.49

# %% [markdown]
# Q3 answer: Pod

# %% [markdown]
# Q4 answer: ClusterIP

# %% [markdown]
# Q5 answer: kind load docker-image

# %% [markdown]
# We finished it!
